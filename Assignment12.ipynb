# %% [markdown]
# ## Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# ### We use Exception class as base class for custom exception class because it is a super class of all errors, all errors are predefined in it so we don't have to define the error occuring in the case.

# %% [markdown]
# ## Q2. Write a python program to print Python Exception Hierarchy.

# %%
import inspect
print("The class hierarchy for built-in exceptions is:")
inspect.getclasstree(inspect.getmro(Exception))
def classtree(cls, indent=0):
    print('.' * indent, cls.__name__)
    for subcls in cls.__subclasses__():
        classtree(subcls, indent + 3)
classtree(Exception)
# Out:
# The class hierarchy for built-in exceptions is:
#  Exception
# ... TypeError
# ...... FloatOperation
# ...... MultipartConversionError
# ... StopAsyncIteration
# ... StopIteration
# ... ImportError
# ...... ModuleNotFoundError
# ...... ZipImportError
# ... OSError
# ...... ConnectionError
# ......... BrokenPipeError
# ......... ConnectionAbortedError
# ......... ConnectionRefusedError
# ......... ConnectionResetError
# ............ RemoteDisconnected
# ...... BlockingIOError
# ...... ChildProcessError
# ...... FileExistsError
# ...... FileNotFoundError
# ...... IsADirectoryError
# ...... NotADirectoryError
# ...... InterruptedError
# ......... InterruptedSystemCall
# ...... PermissionError
# ...... ProcessLookupError
# ...... TimeoutError
# ...... UnsupportedOperation
# ...... itimer_error
# ...... herror
# ...... gaierror
# ...... SSLError
# ......... SSLCertVerificationError
# ......... SSLZeroReturnError
# ......... SSLWantWriteError
# ......... SSLWantReadError
# ...

# %% [markdown]
# ## Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# ## ArithmeticError class in python include:
#   ##  1.OverFlowError
#   ## 2.FloatingPointError
#   ## 3.ZeroDivisionError

# %%
## OverFlowError
j = 5.0

for i in range(1, 1000):
    j = j**i
    print(j)
# Out:
# 5.0
# 25.0
# 15625.0
# 5.960464477539062e+16
# 7.52316384526264e+83
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[3], line 5
#       2 j = 5.0
#       4 for i in range(1, 1000):
# ----> 5     j = j**i
#       6     print(j)
#
# OverflowError: (34, 'Numerical result out of range')

# %%
## ZeroDivisionError
a=-784
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 ## ZeroDivisionError
#       2 a=-784
# ----> 3 a/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# ### The LookupError exception forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively.

# %%
## KeyError
dict1={1:[4,5,"a"],"b":[2,9,"c"]}
dict1["key2"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 ## KeyError
#       2 dict1={1:[4,5,"a"],"b":[2,9,"c"]}
# ----> 3 dict1["key2"]
#
# KeyError: 'key2'

# %%
## Index Error
list1=[1,2,6,["dhwl","krish"],"cricket"]
list1[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 ## Index Error
#       2 list1=[1,2,6,["dhwl","krish"],"cricket"]
# ----> 3 list1[5]
#
# IndexError: list index out of range

# %% [markdown]
# ## Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ### ImportError indicates that the module you are trying to import cannot be imported.

# %% [markdown]
# ### ModuleNotFound is an specific case of ImportError in which module is not found by the python.

# %% [markdown]
# ## Q6. List down some best practices for exception handling in python.

# %% [markdown]
# ### Best practices for Exception Handling in pyhton are:
# ### 1.Always try to use a specific Exception, avoid using Exception class that incudes other exceptions.
# ### 2.Always print a valid message so that the another person using the code understood what kind of error is present and in which part of program.
# ### 3.Always use log in place of print statement because it saves it in different files, so it cannot be lost.
# ### 4.Avoid the multiple Exception Handling.
